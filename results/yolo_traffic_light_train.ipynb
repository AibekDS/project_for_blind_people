# %%
! gdown 1ZwzPzyjPKLH5qDUb9mVTdyPzW9FM-pHH
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1ZwzPzyjPKLH5qDUb9mVTdyPzW9FM-pHH
# To: /content/Traffic_Light_Detection.v1i.yolov8.zip
# 100% 4.97M/4.97M [00:00<00:00, 19.9MB/s]

# %%
! unzip -q /content/Traffic_light.v10i.yolov8.zip
# Out:
# replace README.dataset.txt? [y]es, [n]o, [A]ll, [N]one, [r]ename: A y

# %%
! pip install ultralytics

# %%
from ultralytics import YOLO
import matplotlib.pyplot as plt
from PIL import Image
import cv2
import numpy as np

# %%
# model = YOLO('yolov8n-seg.yaml')
model = YOLO('yolov8l.pt')
# Out:
# ...
# 100%|██████████| 83.7M/83.7M [00:00<00:00, 109MB/s]

# %%
import yaml

with open("/content/data.yaml", 'r') as stream:
    num_classes = str(yaml.safe_load(stream)['nc'])

# %%
num_classes
# Out:
# '4'

# %%
project = '/content/drive/MyDrive/Yolo/results_tl'
name = "200_epoch-"

# %%
results = model.train(data="/content/data.yaml",
                      project = project,
                      name=name,
                      epochs=80,
                      patience=0,
                      batch=10)
# Out:
# Ultralytics 8.3.28 🚀 Python-3.10.12 torch-2.5.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...
